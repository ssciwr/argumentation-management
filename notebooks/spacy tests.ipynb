# %%
import spacy
from spacy.lang.en import English

# %% [markdown]
# # Sentencizer
# https://spacy.io/usage/linguistic-features#sbd

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("This is a sentence. This is another sentence.")
assert doc.has_annotation("SENT_START")
for sent in doc.sents:
    print(sent.text)
# Out:
# This is a sentence.
# This is another sentence.

# %%
name = "../data/Original/iued_test_original.txt"
#name = "../data/Original/iued_test_original.vrt"
with open (name, "r") as myfile:
    data=myfile.read().replace('\n', '')

# %%
print(data)
# Out:
# As part of the product upgrade at the end of twenty thirteen , the Audi A eight gained a number of new features relating to driver assist systems . These new features are the topic of this service T-V programme . We will be looking at the following driver assist systems : Audi Audi active Lane assist , Audi park assist , Audi night vision assist , and the head up display . The changeover from hydraulical steering to electromechanical steering now means that it is possible to offer Audi active lane assist in the Audi A eight as well . Due to the planned steering interventions , this system requires electromechanical steering . Until the product upgrade took place on the Audi A eight , only Audi lane assist was offered on this model , but not the version that actively intervenes in the steering . This version has been available for some time now on the Audi A six and Audi A seven model . Audi active lane assist , which is now available in the Audi A eight , is very similar to the system in the Audi A six and A seven . However , one innovative new feature has been added . If both Audi side assist , the lane change assist , as well as Audi active lane assist , are present in the Audi A eight , then these two assist systems exchange data . Doing so enables the following system optimisation . To date , if the driver changed lane and set a direction indicator while Audi active lane assist was activated , the output of a warning would have been suppressed . It was assumed that the change of lane was intentional . In the new system , this warning is also normally suppressed , but with one exception . If Audi side assist detects an approaching vehicle in the neighbouring lane , a warning is given despite the direction indicator having been set . The warning is given by means of a steering intervention , and , if this is activated in the M-M-I , via a vibration in the steering wheel . As a result , the driver is made aware that changing lane at the present time could lead to an accident . If you would like to learn more about Audi active lane assist , take a look at self-study program four eight three . This booklet describes the technology and functions of the system in detail . Electromechanical steering not only enables active steering intervention in lane assist systems . In future , the driver will also be assisted when driving into parking spaces in the A eight if required . With the introduction of Audi park assist in the Audi A eight , the semiautomated parking system can also be ordered for this class of vehicle . The system has been taken from the Audi A six and A seven , although one major parameter had to be adapted . When parallel parking , the customer will only be told that a parking space is sufficiently long if it is at least the length of the vehicle plus one metre . Audi park assist determines the length of the space using ultrasonic sensors fitted to the side of the vehicle . If you would like to read more about the technology used in Audi park assist , we recommend that you take a look at self-study program six hundred . Audi new driver assist systems in twenty eleven . The driver is offered real added value , even in the dark . Audi night vision assist now boasts a major new function following the Audi A eight product upgrade . To date , night vision assist only detected pedestrians using a thermal imaging camera and highlighted them with yellow brackets . If the system detected a risk of collision with a pedestrian , the system would output a graphic and an acoustic warning . Following the product upgrade , the night vision assist in the Audi A eight now also detects large wild animals and highlights these in the thermal image displayed . The system warns the driver if there is a likelihood of an imminent collision with a wild animal . As a result , the system is able to contribute further to supporting the driver in avoiding accidents . Anyone wishing to find out more information about Audi night vision assist can ...

# %%
doc = nlp(data)
assert doc.has_annotation("SENT_START")
for sent in doc.sents:
    print(sent.text)
    print('***')
# Out:
# As part of the product upgrade at the end of twenty thirteen , the Audi A eight gained a number of new features relating to driver assist systems .
# ***
# These new features are the topic of this service T-V programme .
# ***
# We will be looking at the following driver assist systems : Audi Audi active Lane assist , Audi park assist , Audi night vision assist , and the head up display .
# ***
# The changeover from hydraulical steering to electromechanical steering now means that it is possible to offer Audi active lane assist in the Audi A
# ***
# eight as well .
# ***
# Due to the planned steering interventions , this system requires electromechanical steering .
# ***
# Until the product upgrade took place on the Audi A eight , only Audi lane assist was offered on this model , but not the version that actively intervenes in the steering .
# ***
# This version has been available for some time now on the Audi A six and Audi A seven model .
# ***
# Audi active lane assist , which is now available in the Audi A eight , is very similar to the system in the Audi A six and A seven .
# ***
# However , one innovative new feature has been added .
# ***
# If both Audi side assist , the lane change assist , as well as Audi active lane assist , are present in the Audi A eight , then these two assist systems exchange data .
# ***
# Doing so enables the following system optimisation .
# ***
# To date , if the driver changed lane and set a direction indicator while Audi active lane assist was activated , the output of a warning would have been suppressed .
# ***
# It was assumed that the change of lane was intentional .
# ***
# In the new system , this warning is also normally suppressed , but with one exception .
# ***
# If Audi side assist detects an approaching vehicle in the neighbouring lane , a warning is given despite the direction indicator having been set .
# ***
# The warning is given by means of a steering intervention , and , if this is activated in the M-M-I , via a vibration in the steering wheel .
# ***
# As a result , the driver is made aware that changing lane at the present time could lead to an accident .
# ***
# If you would like to learn more about Audi active lane assist , take a look at self-study program four eight three .
# ***
# This booklet describes the technology and functions of the system in detail .
# ***
# Electromechanical steering not only enables active steering intervention in lane assist systems .
# ***
# In future , the driver will also be assisted when driving into parking spaces in the A eight if required .
# ***
# With the introduction of Audi park assist in the Audi A eight , the semiautomated parking system can also be ordered for this class of vehicle .
# ***
# The system has been taken from the Audi A six
# ***
# and A seven , although one major parameter had to be adapted .
# ***
# When parallel parking , the customer will only be told that a parking space is sufficiently long if it is at least the length of the vehicle plus one metre .
# ***
# Audi park assist determines the length of the space using ultrasonic sensors fitted to the side of the vehicle .
# ***
# If you would like to read more about the technology used in Audi park assist , we recommend that you take a look at self-study program six hundred .
# ***
# Audi new driver assist systems in twenty eleven .
# ***
# The driver is offered real added value , even in the dark .
# ***
# Audi night vision assist now boasts a major new function following the Audi A eight product upgrade .
# ***
# To date , night vision assist only detected pedestrians using a thermal imaging camera and highlighted them with yellow brackets .
# ***
# If the system detected a risk of collision with a pedestrian , the system would output a graphic and an acoustic warning .
# ***
# Following the product upgrade , the night vision assist in the Audi A eight now also detects large wild animals and highlights these in the thermal image displayed .
# ***
# The system warns the driver if there is a likelihood of an imminent collision with a wild animal .
# ***
# As a result , the system is able to contribute further to supporting the driver in avoiding accidents .
# ***
# Anyone wishing to find out more information about Audi night vision assist can take a look at self-study program four six two .
# ***
# Audi A eight ten , night vision assist .
# ***
# The head-up display resulting from the Audi A eight product upgrade is mainly based on the head up display in the Audi C seven .
# ***
# Only a few details have been modified .
# ***
# The displays are the same , apart from one exception .
# ***
# The combined display of adaptive cruise control and Audi active lane assist has been removed .
# ***
# Instead , a red warning symbol for the distance and collision warning system is projected onto the windscreen .
# ***
# The procedure for calibrating the head up display in customer service has remained the same as for the Audi A six and A seven .
# ***
# If you wish to learn more about the head up display , please take a look at self-study program four eight two .
# ***
# Audi A seven Sportback , head-up display and speed limit indicator .
# ***
# Anything you need to know about this system is described in this booklet .
# ***
# We always want to improve our programmes .
# ***
# Please send any suggestions , improvements and topic requests you may have to Audi dot service dot T-V at Audi dot D-E .
# ***

# %% [markdown]
# This gives somewhat accurate results, with some errors after numbers. You can also use a trained model, however this will not work on uncommon texts.

# %%
doc = nlp(data)
for sent in doc.sents:
    print(sent.text)
    print('***')
# Out:
# As part of the product upgrade at the end of twenty thirteen , the Audi A eight gained a number of new features relating to driver assist systems .
# ***
# These new features are the topic of this service T-V programme .
# ***
# We will be looking at the following driver assist systems : Audi Audi active Lane assist , Audi park assist , Audi night vision assist , and the head up display .
# ***
# The changeover from hydraulical steering to electromechanical steering now means that it is possible to offer Audi active lane assist in the Audi A
# ***
# eight as well .
# ***
# Due to the planned steering interventions , this system requires electromechanical steering .
# ***
# Until the product upgrade took place on the Audi A eight , only Audi lane assist was offered on this model , but not the version that actively intervenes in the steering .
# ***
# This version has been available for some time now on the Audi A six and Audi A seven model .
# ***
# Audi active lane assist , which is now available in the Audi A eight , is very similar to the system in the Audi A six and A seven .
# ***
# However , one innovative new feature has been added .
# ***
# If both Audi side assist , the lane change assist , as well as Audi active lane assist , are present in the Audi A eight , then these two assist systems exchange data .
# ***
# Doing so enables the following system optimisation .
# ***
# To date , if the driver changed lane and set a direction indicator while Audi active lane assist was activated , the output of a warning would have been suppressed .
# ***
# It was assumed that the change of lane was intentional .
# ***
# In the new system , this warning is also normally suppressed , but with one exception .
# ***
# If Audi side assist detects an approaching vehicle in the neighbouring lane , a warning is given despite the direction indicator having been set .
# ***
# The warning is given by means of a steering intervention , and , if this is activated in the M-M-I , via a vibration in the steering wheel .
# ***
# As a result , the driver is made aware that changing lane at the present time could lead to an accident .
# ***
# If you would like to learn more about Audi active lane assist , take a look at self-study program four eight three .
# ***
# This booklet describes the technology and functions of the system in detail .
# ***
# Electromechanical steering not only enables active steering intervention in lane assist systems .
# ***
# In future , the driver will also be assisted when driving into parking spaces in the A eight if required .
# ***
# With the introduction of Audi park assist in the Audi A eight , the semiautomated parking system can also be ordered for this class of vehicle .
# ***
# The system has been taken from the Audi A six
# ***
# and A seven , although one major parameter had to be adapted .
# ***
# When parallel parking , the customer will only be told that a parking space is sufficiently long if it is at least the length of the vehicle plus one metre .
# ***
# Audi park assist determines the length of the space using ultrasonic sensors fitted to the side of the vehicle .
# ***
# If you would like to read more about the technology used in Audi park assist , we recommend that you take a look at self-study program six hundred .
# ***
# Audi new driver assist systems in twenty eleven .
# ***
# The driver is offered real added value , even in the dark .
# ***
# Audi night vision assist now boasts a major new function following the Audi A eight product upgrade .
# ***
# To date , night vision assist only detected pedestrians using a thermal imaging camera and highlighted them with yellow brackets .
# ***
# If the system detected a risk of collision with a pedestrian , the system would output a graphic and an acoustic warning .
# ***
# Following the product upgrade , the night vision assist in the Audi A eight now also detects large wild animals and highlights these in the thermal image displayed .
# ***
# The system warns the driver if there is a likelihood of an imminent collision with a wild animal .
# ***
# As a result , the system is able to contribute further to supporting the driver in avoiding accidents .
# ***
# Anyone wishing to find out more information about Audi night vision assist can take a look at self-study program four six two .
# ***
# Audi A eight ten , night vision assist .
# ***
# The head-up display resulting from the Audi A eight product upgrade is mainly based on the head up display in the Audi C seven .
# ***
# Only a few details have been modified .
# ***
# The displays are the same , apart from one exception .
# ***
# The combined display of adaptive cruise control and Audi active lane assist has been removed .
# ***
# Instead , a red warning symbol for the distance and collision warning system is projected onto the windscreen .
# ***
# The procedure for calibrating the head up display in customer service has remained the same as for the Audi A six and A seven .
# ***
# If you wish to learn more about the head up display , please take a look at self-study program four eight two .
# ***
# Audi A seven Sportback , head-up display and speed limit indicator .
# ***
# Anything you need to know about this system is described in this booklet .
# ***
# We always want to improve our programmes .
# ***
# Please send any suggestions , improvements and topic requests you may have to Audi dot service dot T-V at Audi dot D-E .
# ***

# %% [markdown]
# Also fails for the example here. Then there is the one based on a statistical model.

# %%
nlp.enable_pipe("senter")
doc = nlp(data)
for sent in doc.sents:
    print(sent.text)
    print('***')
# Out:
# As part of the product upgrade at the end of twenty thirteen , the Audi A eight gained a number of new features relating to driver assist systems .
# ***
# These new features are the topic of this service T-V programme .
# ***
# We will be looking at the following driver assist systems : Audi Audi active Lane assist , Audi park assist , Audi night vision assist , and the head up display .
# ***
# The changeover from hydraulical steering to electromechanical steering now means that it is possible to offer Audi active lane assist in the Audi A
# ***
# eight as well .
# ***
# Due to the planned steering interventions , this system requires electromechanical steering .
# ***
# Until the product upgrade took place on the Audi A eight , only Audi lane assist was offered on this model , but not the version that actively intervenes in the steering .
# ***
# This version has been available for some time now on the Audi A six and Audi A seven model .
# ***
# Audi active lane assist , which is now available in the Audi A eight , is very similar to the system in the Audi A six and A seven .
# ***
# However , one innovative new feature has been added .
# ***
# If both Audi side assist , the lane change assist , as well as Audi active lane assist , are present in the Audi A eight , then these two assist systems exchange data .
# ***
# Doing so enables the following system optimisation .
# ***
# To date , if the driver changed lane and set a direction indicator while Audi active lane assist was activated , the output of a warning would have been suppressed .
# ***
# It was assumed that the change of lane was intentional .
# ***
# In the new system , this warning is also normally suppressed , but with one exception .
# ***
# If Audi side assist detects an approaching vehicle in the neighbouring lane , a warning is given despite the direction indicator having been set .
# ***
# The warning is given by means of a steering intervention , and , if this is activated in the M-M-I , via a vibration in the steering wheel .
# ***
# As a result , the driver is made aware that changing lane at the present time could lead to an accident .
# ***
# If you would like to learn more about Audi active lane assist , take a look at self-study program four eight three .
# ***
# This booklet describes the technology and functions of the system in detail .
# ***
# Electromechanical steering not only enables active steering intervention in lane assist systems .
# ***
# In future , the driver will also be assisted when driving into parking spaces in the A eight if required .
# ***
# With the introduction of Audi park assist in the Audi A eight , the semiautomated parking system can also be ordered for this class of vehicle .
# ***
# The system has been taken from the Audi A six
# ***
# and A seven , although one major parameter had to be adapted .
# ***
# When parallel parking , the customer will only be told that a parking space is sufficiently long if it is at least the length of the vehicle plus one metre .
# ***
# Audi park assist determines the length of the space using ultrasonic sensors fitted to the side of the vehicle .
# ***
# If you would like to read more about the technology used in Audi park assist , we recommend that you take a look at self-study program six hundred .
# ***
# Audi new driver assist systems in twenty eleven .
# ***
# The driver is offered real added value , even in the dark .
# ***
# Audi night vision assist now boasts a major new function following the Audi A eight product upgrade .
# ***
# To date , night vision assist only detected pedestrians using a thermal imaging camera and highlighted them with yellow brackets .
# ***
# If the system detected a risk of collision with a pedestrian , the system would output a graphic and an acoustic warning .
# ***
# Following the product upgrade , the night vision assist in the Audi A eight now also detects large wild animals and highlights these in the thermal image displayed .
# ***
# The system warns the driver if there is a likelihood of an imminent collision with a wild animal .
# ***
# As a result , the system is able to contribute further to supporting the driver in avoiding accidents .
# ***
# Anyone wishing to find out more information about Audi night vision assist can take a look at self-study program four six two .
# ***
# Audi A eight ten , night vision assist .
# ***
# The head-up display resulting from the Audi A eight product upgrade is mainly based on the head up display in the Audi C seven .
# ***
# Only a few details have been modified .
# ***
# The displays are the same , apart from one exception .
# ***
# The combined display of adaptive cruise control and Audi active lane assist has been removed .
# ***
# Instead , a red warning symbol for the distance and collision warning system is projected onto the windscreen .
# ***
# The procedure for calibrating the head up display in customer service has remained the same as for the Audi A six and A seven .
# ***
# If you wish to learn more about the head up display , please take a look at self-study program four eight two .
# ***
# Audi A seven Sportback , head-up display and speed limit indicator .
# ***
# Anything you need to know about this system is described in this booklet .
# ***
# We always want to improve our programmes .
# ***
# Please send any suggestions , improvements and topic requests you may have to Audi dot service dot T-V at Audi dot D-E .
# ***

# %% [markdown]
# Directly use the sentencizer without the pipeline - this one looks at punctuation.

# %%
nlp = English()  # just the language with no pipeline
nlp.add_pipe("sentencizer")
doc = nlp(data)
for sent in doc.sents:
    print(sent.text)
    print('***')
# Out:
# As part of the product upgrade at the end of twenty thirteen , the Audi A eight gained a number of new features relating to driver assist systems .
# ***
# These new features are the topic of this service T-V programme .
# ***
# We will be looking at the following driver assist systems : Audi Audi active Lane assist , Audi park assist , Audi night vision assist , and the head up display .
# ***
# The changeover from hydraulical steering to electromechanical steering now means that it is possible to offer Audi active lane assist in the Audi A eight as well .
# ***
# Due to the planned steering interventions , this system requires electromechanical steering .
# ***
# Until the product upgrade took place on the Audi A eight , only Audi lane assist was offered on this model , but not the version that actively intervenes in the steering .
# ***
# This version has been available for some time now on the Audi A six and Audi A seven model .
# ***
# Audi active lane assist , which is now available in the Audi A eight , is very similar to the system in the Audi A six and A seven .
# ***
# However , one innovative new feature has been added .
# ***
# If both Audi side assist , the lane change assist , as well as Audi active lane assist , are present in the Audi A eight , then these two assist systems exchange data .
# ***
# Doing so enables the following system optimisation .
# ***
# To date , if the driver changed lane and set a direction indicator while Audi active lane assist was activated , the output of a warning would have been suppressed .
# ***
# It was assumed that the change of lane was intentional .
# ***
# In the new system , this warning is also normally suppressed , but with one exception .
# ***
# If Audi side assist detects an approaching vehicle in the neighbouring lane , a warning is given despite the direction indicator having been set .
# ***
# The warning is given by means of a steering intervention , and , if this is activated in the M-M-I , via a vibration in the steering wheel .
# ***
# As a result , the driver is made aware that changing lane at the present time could lead to an accident .
# ***
# If you would like to learn more about Audi active lane assist , take a look at self-study program four eight three .
# ***
# This booklet describes the technology and functions of the system in detail .
# ***
# Electromechanical steering not only enables active steering intervention in lane assist systems .
# ***
# In future , the driver will also be assisted when driving into parking spaces in the A eight if required .
# ***
# With the introduction of Audi park assist in the Audi A eight , the semiautomated parking system can also be ordered for this class of vehicle .
# ***
# The system has been taken from the Audi A six and A seven , although one major parameter had to be adapted .
# ***
# When parallel parking , the customer will only be told that a parking space is sufficiently long if it is at least the length of the vehicle plus one metre .
# ***
# Audi park assist determines the length of the space using ultrasonic sensors fitted to the side of the vehicle .
# ***
# If you would like to read more about the technology used in Audi park assist , we recommend that you take a look at self-study program six hundred .
# ***
# Audi new driver assist systems in twenty eleven .
# ***
# The driver is offered real added value , even in the dark .
# ***
# Audi night vision assist now boasts a major new function following the Audi A eight product upgrade .
# ***
# To date , night vision assist only detected pedestrians using a thermal imaging camera and highlighted them with yellow brackets .
# ***
# If the system detected a risk of collision with a pedestrian , the system would output a graphic and an acoustic warning .
# ***
# Following the product upgrade , the night vision assist in the Audi A eight now also detects large wild animals and highlights these in the thermal image displayed .
# ***
# The system warns the driver if there is a likelihood of an imminent collision with a wild animal .
# ***
# As a result , the system is able to contribute further to supporting the driver in avoiding accidents .
# ***
# Anyone wishing to find out more information about Audi night vision assist can take a look at self-study program four six two .
# ***
# Audi A eight ten , night vision assist .
# ***
# The head-up display resulting from the Audi A eight product upgrade is mainly based on the head up display in the Audi C seven .
# ***
# Only a few details have been modified .
# ***
# The displays are the same , apart from one exception .
# ***
# The combined display of adaptive cruise control and Audi active lane assist has been removed .
# ***
# Instead , a red warning symbol for the distance and collision warning system is projected onto the windscreen .
# ***
# The procedure for calibrating the head up display in customer service has remained the same as for the Audi A six and A seven .
# ***
# If you wish to learn more about the head up display , please take a look at self-study program four eight two .
# ***
# Audi A seven Sportback , head-up display and speed limit indicator .
# ***
# Anything you need to know about this system is described in this booklet .
# ***
# We always want to improve our programmes .
# ***
# Please send any suggestions , improvements and topic requests you may have to Audi dot service dot T-V at Audi dot D-E .
# ***

# %% [markdown]
# Seems to work correctly. What is the difference to the pipeline? In the DW scripts, the other components are disabled via the "exclude" command - should be faster as pipeline is not loaded at all.

# %%
texts = [
    "Net income was $9.4 million compared to the prior year of $2.7 million.",
    "Revenue exceeded twelve billion dollars, with a loss of $1b.",
]

nlp = spacy.load("en_core_web_sm")
for doc in nlp.pipe(texts, disable=["tok2vec", "tagger", "parser", "attribute_ruler", "lemmatizer"]):
    # Do something with the doc here
    print([(ent.text, ent.label_) for ent in doc.ents])
# Out:
# [('$9.4 million', 'MONEY'), ('the prior year', 'DATE'), ('$2.7 million', 'MONEY')]
# [('twelve billion dollars', 'MONEY'), ('1b', 'MONEY')]

# %%
nlp = spacy.load("en_core_web_sm", exclude=["tagger", "ner", "attribute_ruler", "lemmatizer"])
for doc in nlp.pipe(texts):
    for sent in doc.sents:
        print(sent.text)
        print('***')
# Out:
# Net income was $9.4 million compared to the prior year of $2.7 million.
# ***
# Revenue exceeded twelve billion dollars, with a loss of $1b.
# ***

# %% [markdown]
# # Tokenizer
# https://spacy.io/usage/linguistic-features#tokenization
# We need to allow for special case rules.
# ```
# special_case = [{ORTH: "gim"}, {ORTH: "me"}]
# nlp.tokenizer.add_special_case("gimme", special_case)
# ```
#
# Also, there are custom tokenizer libraries that one may want to load. Probably we would want to keep it so that users can specify their custom tokenizers in addition to the standard one from spaCy.

# %%
doc = nlp(data)
for token in doc:
    print(token.text)
# Out:
# As
# part
# of
# the
# product
# upgrade
# at
# the
# end
# of
# twenty
# thirteen
# ,
# the
# Audi
# A
# eight
# gained
# a
# number
# of
# new
# features
# relating
# to
# driver
# assist
# systems
# .
# These
# new
# features
# are
# the
# topic
# of
# this
# service
# T
# -
# V
# programme
# .
# We
# will
# be
# looking
# at
# the
# following
# driver
# assist
# systems
# :
# Audi
# Audi
# active
# Lane
# assist
# ,
# Audi
# park
# assist
# ,
# Audi
# night
# vision
# assist
# ,
# and
# the
# head
# up
# display
# .
# The
# changeover
# from
# hydraulical
# steering
# to
# electromechanical
# steering
# now
# means
# that
# it
# is
# possible
# to
# offer
# Audi
# active
# lane
# assist
# in
# the
# Audi
# A
# eight
# as
# well
# .
# Due
# to
# the
# planned
# steering
# interventions
# ,
# this
# system
# requires
# electromechanical
# steering
# .
# Until
# the
# product
# upgrade
# took
# place
# on
# the
# Audi
# A
# eight
# ,
# only
# Audi
# lane
# assist
# was
# offered
# on
# this
# model
# ,
# but
# not
# the
# version
# that
# actively
# intervenes
# in
# the
# steering
# .
# This
# version
# has
# been
# available
# for
# some
# time
# now
# on
# the
# Audi
# A
# six
# and
# Audi
# A
# seven
# model
# .
# Audi
# active
# lane
# assist
# ,
# which
# is
# now
# available
# in
# the
# Audi
# A
# eight
# ,
# is
# very
# similar
# to
# the
# system
# in
# the
# Audi
# A
# six
# and
# A
# seven
# .
# However
# ,
# one
# innovative
# new
# feature
# has
# been
# added
# .
# If
# both
# Audi
# side
# assist
# ,
# the
# lane
# change
# assist
# ,
# as
# well
# as
# Audi
# active
# lane
# assist
# ,
# are
# present
# in
# the
# Audi
# A
# eight
# ,
# then
# these
# two
# assist
# systems
# exchange
# data
# .
# Doing
# so
# enables
# the
# following
# system
# optimisation
# .
# To
# date
# ,
# if
# the
# driver
# changed
# lane
# and
# set
# a
# direction
# indicator
# while
# Audi
# active
# lane
# assist
# was
# activated
# ,
# the
# output
# of
# a
# warning
# would
# have
# been
# suppressed
# .
# It
# was
# assumed
# that
# the
# change
# of
# lane
# was
# intentional
# .
# In
# the
# new
# system
# ,
# this
# warning
# is
# also
# normally
# suppressed
# ,
# but
# with
# one
# exception
# .
# If
# Audi
# side
# assist
# detects
# an
# approaching
# vehicle
# in
# the
# neighbouring
# lane
# ,
# a
# warning
# is
# given
# despite
# the
# direction
# indicator
# having
# been
# set
# .
# The
# warning
# is
# given
# by
# means
# of
# a
# steering
# intervention
# ,
# and
# ,
# if
# this
# is
# activated
# in
# the
# M
# -
# M
# -
# I
# ,
# via
# a
# vibration
# in
# the
# steering
# wheel
# .
# As
# a
# result
# ,
# the
# driver
# is
# made
# aware
# that
# changing
# lane
# at
# the
# present
# time
# could
# lead
# to
# an
# accident
# .
# If
# you
# would
# like
# to
# learn
# more
# about
# Audi
# active
# lane
# assist
# ,
# take
# a
# look
# at
# self
# -
# study
# program
# four
# eight
# three
# .
# This
# booklet
# describes
# the
# technology
# and
# functions
# of
# the
# system
# in
# detail
# .
# Electromechanical
# steering
# not
# only
# enables
# active
# steering
# intervention
# in
# lane
# assist
# systems
# .
# In
# future
# ,
# the
# driver
# will
# also
# be
# assisted
# when
# driving
# into
# parking
# spaces
# in
# the
# A
# eight
# if
# required
# .
# With
# the
# introduction
# of
# Audi
# park
# assist
# in
# the
# Audi
# A
# eight
# ,
# the
# semiautomated
# parking
# system
# can
# also
# be
# ordered
# for
# this
# class
# of
# vehicle
# .
# The
# system
# has
# been
# taken
# from
# the
# Audi
# A
# six
# and
# A
# seven
# ,
# although
# one
# major
# parameter
# had
# to
# be
# adapted
# .
# When
# parallel
# parking
# ,
# the
# customer
# will
# only
# be
# told
# that
# a
# parking
# space
# is
# sufficiently
# long
# if
# it
# is
# at
# least
# the
# length
# of
# the
# vehicle
# plus
# one
# metre
# .
# Audi
# park
# assist
# determines
# the
# length
# of
# the
# space
# using
# ultrasonic
# sensors
# fitted
# to
# the
# side
# of
# the
# vehicle
# .
# If
# you
# would
# like
# to
# read
# more
# about
# the
# technology
# used
# in
# Audi
# park
# assist
# ,
# we
# recommend
# that
# you
# take
# a
# look
# at
# self
# -
# study
# program
# six
# hundred
# .
# Audi
# new
# driver
# assist
# systems
# in
# twenty
# eleven
# .
# The
# driver
# is
# offered
# real
# added
# value
# ,
# even
# in
# the
# dark
# .
# Audi
# night
# vision
# assist
# now
# boasts
# a
# major
# new
# function
# following
# the
# Audi
# A
# eight
# product
# upgrade
# .
# To
# date
# ,
# night
# vision
# assist
# only
# detected
# pedestrians
# using
# a
# thermal
# imaging
# camera
# and
# highlighted
# them
# with
# yellow
# brackets
# .
# If
# the
# system
# detected
# a
# risk
# of
# collision
# with
# a
# pedestrian
# ,
# the
# system
# would
# output
# a
# graphic
# and
# an
# acoustic
# warning
# .
# Following
# the
# product
# upgrade
# ,
# the
# night
# vision
# assist
# in
# the
# Audi
# A
# eight
# now
# also
# detects
# large
# wild
# animals
# and
# highlights
# these
# in
# the
# thermal
# image
# displayed
# .
# The
# system
# warns
# the
# driver
# if
# there
# is
# a
# likelihood
# of
# an
# imminent
# collision
# with
# a
# wild
# animal
# .
# As
# a
# result
# ,
# the
# system
# is
# able
# to
# contribute
# further
# to
# supporting
# the
# driver
# in
# avoiding
# accidents
# .
# Anyone
# wishing
# to
# find
# out
# more
# information
# about
# Audi
# night
# vision
# assist
# can
# take
# a
# look
# at
# self
# -
# study
# program
# four
# six
# two
# .
# Audi
# A
# eight
# ten
# ,
# night
# vision
# assist
# .
# The
# head
# -
# up
# display
# resulting
# from
# the
# Audi
# A
# eight
# product
# upgrade
# is
# mainly
# based
# on
# the
# head
# up
# display
# in
# the
# Audi
# C
# seven
# .
# Only
# a
# few
# details
# have
# been
# modified
# .
# The
# displays
# are
# the
# same
# ,
# apart
# from
# one
# exception
# .
# The
# combined
# display
# of
# adaptive
# cruise
# control
# and
# Audi
# active
# lane
# assist
# has
# been
# removed
# .
# Instead
# ,
# a
# red
# warning
# symbol
# for
# the
# distance
# and
# collision
# warning
# system
# is
# projected
# onto
# the
# windscreen
# .
# The
# procedure
# for
# calibrating
# the
# head
# up
# display
# in
# customer
# service
# has
# remained
# the
# same
# as
# for
# the
# Audi
# A
# six
# and
# A
# seven
# .
# If
# you
# wish
# to
# learn
# more
# about
# the
# head
# up
# display
# ,
# please
# take
# a
# look
# at
# self
# -
# study
# program
# four
# eight
# two
# .
# Audi
# A
# seven
# Sportback
# ,
# head
# -
# up
# display
# and
# speed
# limit
# indicator
# .
# Anything
# you
# need
# to
# know
# about
# this
# system
# is
# described
# in
# this
# booklet
# .
# We
# always
# want
# to
# improve
# our
# programmes
# .
# Please
# send
# any
# suggestions
# ,
# improvements
# and
# topic
# requests
# you
# may
# have
# to
# Audi
# dot
# service
# dot
# T
# -
# V
# at
# Audi
# dot
# D
# -
# E
# .

# %% [markdown]
# # Lemmatizer
# https://spacy.io/usage/linguistic-features#lemmatization
#
# needs package spacy_lookups_data to run

# %%
lemmatizer = nlp.add_pipe("lemmatizer")  # need to be carefull which components are already in the pipeline or not. get_pipe() throws me an error when running this from the top
print(lemmatizer.mode)  # 'rule'
lemmatizer.initialize(lookups=None)
doc = nlp("I was reading the paper.")
print([token.lemma_ for token in doc])
# Out:
# rule
# ['i', 'was', 'reading', 'the', 'paper', '.']
# /home/christian/anaconda3/envs/cwbproj/lib/python3.8/site-packages/spacy/pipeline/lemmatizer.py:187: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %%
doc = nlp(data)
print([token.lemma_ for token in doc])
# Out:
# ['as', 'part', 'of', 'the', 'product', 'upgrade', 'at', 'the', 'end', 'of', 'twenty', 'thirteen', ',', 'the', 'audi', 'a', 'eight', 'gained', 'a', 'number', 'of', 'new', 'features', 'relating', 'to', 'driver', 'assist', 'systems', '.', 'these', 'new', 'features', 'are', 'the', 'topic', 'of', 'this', 'service', 't', '-', 'v', 'programme', '.', 'we', 'will', 'be', 'looking', 'at', 'the', 'following', 'driver', 'assist', 'systems', ':', 'audi', 'audi', 'active', 'lane', 'assist', ',', 'audi', 'park', 'assist', ',', 'audi', 'night', 'vision', 'assist', ',', 'and', 'the', 'head', 'up', 'display', '.', 'the', 'changeover', 'from', 'hydraulical', 'steering', 'to', 'electromechanical', 'steering', 'now', 'means', 'that', 'it', 'is', 'possible', 'to', 'offer', 'audi', 'active', 'lane', 'assist', 'in', 'the', 'audi', 'a', 'eight', 'as', 'well', '.', 'due', 'to', 'the', 'planned', 'steering', 'interventions', ',', 'this', 'system', 'requires', 'electromechanical', 'steering', '.', 'until', 'the', 'product', 'upgrade', 'took', 'place', 'on', 'the', 'audi', 'a', 'eight', ',', 'only', 'audi', 'lane', 'assist', 'was', 'offered', 'on', 'this', 'model', ',', 'but', 'not', 'the', 'version', 'that', 'actively', 'intervenes', 'in', 'the', 'steering', '.', 'this', 'version', 'has', 'been', 'available', 'for', 'some', 'time', 'now', 'on', 'the', 'audi', 'a', 'six', 'and', 'audi', 'a', 'seven', 'model', '.', 'audi', 'active', 'lane', 'assist', ',', 'which', 'is', 'now', 'available', 'in', 'the', 'audi', 'a', 'eight', ',', 'is', 'very', 'similar', 'to', 'the', 'system', 'in', 'the', 'audi', 'a', 'six', 'and', 'a', 'seven', '.', 'however', ',', 'one', 'innovative', 'new', 'feature', 'has', 'been', 'added', '.', 'if', 'both', 'audi', 'side', 'assist', ',', 'the', 'lane', 'change', 'assist', ',', 'as', 'well', 'as', 'audi', 'active', 'lane', 'assist', ',', 'are', 'present', 'in', 'the', 'audi', 'a', 'eight', ',', 'then', 'these', 'two', 'assist', 'systems', 'exchange', 'data', '.', 'doing', 'so', 'enables', 'the', 'following', 'system', 'optimisation', '.', 'to', 'date', ',', 'if', 'the', 'driver', 'changed', 'lane', 'and', 'set', 'a', 'direction', 'indicator', 'while', 'audi', 'active', 'lane', 'assist', 'was', 'activated', ',', 'the', 'output', 'of', 'a', 'warning', 'would', 'have', 'been', 'suppressed', '.', 'it', 'was', 'assumed', 'that', 'the', 'change', 'of', 'lane', 'was', 'intentional', '.', 'in', 'the', 'new', 'system', ',', 'this', 'warning', 'is', 'also', 'normally', 'suppressed', ',', 'but', 'with', 'one', 'exception', '.', 'if', 'audi', 'side', 'assist', 'detects', 'an', 'approaching', 'vehicle', 'in', 'the', 'neighbouring', 'lane', ',', 'a', 'warning', 'is', 'given', 'despite', 'the', 'direction', 'indicator', 'having', 'been', 'set', '.', 'the', 'warning', 'is', 'given', 'by', 'means', 'of', 'a', 'steering', 'intervention', ',', 'and', ',', 'if', 'this', 'is', 'activated', 'in', 'the', 'm', '-', 'm', '-', 'i', ',', 'via', 'a', 'vibration', 'in', 'the', 'steering', 'wheel', '.', 'as', 'a', 'result', ',', 'the', 'driver', 'is', 'made', 'aware', 'that', 'changing', 'lane', 'at', 'the', 'present', 'time', 'could', 'lead', 'to', 'an', 'accident', '.', 'if', 'you', 'would', 'like', 'to', 'learn', 'more', 'about', 'audi', 'active', 'lane', 'assist', ',', 'take', 'a', 'look', 'at', 'self', '-', 'study', 'program', 'four', 'eight', 'three', '.', 'this', 'booklet', 'describes', 'the', 'technology', 'and', 'functions', 'of', 'the', 'system', 'in', 'detail', '.', 'electromechanical', 'steering', 'not', 'only', 'enables', 'active', 'steering', 'intervention', 'in', 'lane', 'assist', 'systems', '.', 'in', 'future', ',', 'the', 'driver', 'will', 'also', 'be', 'assisted', 'when', 'driving', 'into', 'parking', 'spaces', 'in', 'the', 'a', 'eight', 'if', 'required', '.', 'with', 'the', 'introduction', 'of', 'audi', 'park', 'assist', 'in', 'the', 'audi', 'a', 'eight', ',', 'the', 'semiautomated', 'parking', 'system', 'can', 'also', 'be', 'ordered', 'for', 't ...

# %% [markdown]
# Should punctuation be excluded?

# %% [markdown]
# # POS tagger
# https://spacy.io/usage/linguistic-features#pos-tagging

# %%
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# Apple apple   nsubj Xxxxx True False
# is is   aux xx True True
# looking looking   ROOT xxxx True False
# at at   prep xx True True
# buying buying   pcomp xxxx True False
# U.K. u.k.   compound X.X. False False
# startup startup   dobj xxxx True False
# for for   prep xxx True True
# $ $   quantmod $ False False
# 1 1   compound d False False
# billion billion   pobj xxxx True False

# %%
doc = nlp(data)
for token in doc:
    print(token.text, token.pos_, token.tag_)
# Out:
# As
# part
# of
# the
# product
# upgrade
# at
# the
# end
# of
# twenty
# thirteen
# ,
# the
# Audi
# A
# eight
# gained
# a
# number
# of
# new
# features
# relating
# to
# driver
# assist
# systems
# .
# These
# new
# features
# are
# the
# topic
# of
# this
# service
# T
# -
# V
# programme
# .
# We
# will
# be
# looking
# at
# the
# following
# driver
# assist
# systems
# :
# Audi
# Audi
# active
# Lane
# assist
# ,
# Audi
# park
# assist
# ,
# Audi
# night
# vision
# assist
# ,
# and
# the
# head
# up
# display
# .
# The
# changeover
# from
# hydraulical
# steering
# to
# electromechanical
# steering
# now
# means
# that
# it
# is
# possible
# to
# offer
# Audi
# active
# lane
# assist
# in
# the
# Audi
# A
# eight
# as
# well
# .
# Due
# to
# the
# planned
# steering
# interventions
# ,
# this
# system
# requires
# electromechanical
# steering
# .
# Until
# the
# product
# upgrade
# took
# place
# on
# the
# Audi
# A
# eight
# ,
# only
# Audi
# lane
# assist
# was
# offered
# on
# this
# model
# ,
# but
# not
# the
# version
# that
# actively
# intervenes
# in
# the
# steering
# .
# This
# version
# has
# been
# available
# for
# some
# time
# now
# on
# the
# Audi
# A
# six
# and
# Audi
# A
# seven
# model
# .
# Audi
# active
# lane
# assist
# ,
# which
# is
# now
# available
# in
# the
# Audi
# A
# eight
# ,
# is
# very
# similar
# to
# the
# system
# in
# the
# Audi
# A
# six
# and
# A
# seven
# .
# However
# ,
# one
# innovative
# new
# feature
# has
# been
# added
# .
# If
# both
# Audi
# side
# assist
# ,
# the
# lane
# change
# assist
# ,
# as
# well
# as
# Audi
# active
# lane
# assist
# ,
# are
# present
# in
# the
# Audi
# A
# eight
# ,
# then
# these
# two
# assist
# systems
# exchange
# data
# .
# Doing
# so
# enables
# the
# following
# system
# optimisation
# .
# To
# date
# ,
# if
# the
# driver
# changed
# lane
# and
# set
# a
# direction
# indicator
# while
# Audi
# active
# lane
# assist
# was
# activated
# ,
# the
# output
# of
# a
# warning
# would
# have
# been
# suppressed
# .
# It
# was
# assumed
# that
# the
# change
# of
# lane
# was
# intentional
# .
# In
# the
# new
# system
# ,
# this
# warning
# is
# also
# normally
# suppressed
# ,
# but
# with
# one
# exception
# .
# If
# Audi
# side
# assist
# detects
# an
# approaching
# vehicle
# in
# the
# neighbouring
# lane
# ,
# a
# warning
# is
# given
# despite
# the
# direction
# indicator
# having
# been
# set
# .
# The
# warning
# is
# given
# by
# means
# of
# a
# steering
# intervention
# ,
# and
# ,
# if
# this
# is
# activated
# in
# the
# M
# -
# M
# -
# I
# ,
# via
# a
# vibration
# in
# the
# steering
# wheel
# .
# As
# a
# result
# ,
# the
# driver
# is
# made
# aware
# that
# changing
# lane
# at
# the
# present
# time
# could
# lead
# to
# an
# accident
# .
# If
# you
# would
# like
# to
# learn
# more
# about
# Audi
# active
# lane
# assist
# ,
# take
# a
# look
# at
# self
# -
# study
# program
# four
# eight
# three
# .
# This
# booklet
# describes
# the
# technology
# and
# functions
# of
# the
# system
# in
# detail
# .
# Electromechanical
# steering
# not
# only
# enables
# active
# steering
# intervention
# in
# lane
# assist
# systems
# .
# In
# future
# ,
# the
# driver
# will
# also
# be
# assisted
# when
# driving
# into
# parking
# spaces
# in
# the
# A
# eight
# if
# required
# .
# With
# the
# introduction
# of
# Audi
# park
# assist
# in
# the
# Audi
# A
# eight
# ,
# the
# semiautomated
# parking
# system
# can
# also
# be
# ordered
# for
# this
# class
# of
# vehicle
# .
# The
# system
# has
# been
# taken
# from
# the
# Audi
# A
# six
# and
# A
# seven
# ,
# although
# one
# major
# parameter
# had
# to
# be
# adapted
# .
# When
# parallel
# parking
# ,
# the
# customer
# will
# only
# be
# told
# that
# a
# parking
# space
# is
# sufficiently
# long
# if
# it
# is
# at
# least
# the
# length
# of
# the
# vehicle
# plus
# one
# metre
# .
# Audi
# park
# assist
# determines
# the
# length
# of
# the
# space
# using
# ultrasonic
# sensors
# fitted
# to
# the
# side
# of
# the
# vehicle
# .
# If
# you
# would
# like
# to
# read
# more
# about
# the
# technology
# used
# in
# Audi
# park
# assist
# ,
# we
# recommend
# that
# you
# take
# a
# look
# at
# self
# -
# study
# program
# six
# hundred
# .
# Audi
# new
# driver
# assist
# systems
# in
# twenty
# eleven
# .
# The
# driver
# is
# offered
# real
# added
# value
# ,
# even
# in
# the
# dark
# .
# Audi
# night
# vision
# assist
# now
# boasts
# a
# major
# new
# function
# following
# the
# Audi
# A
# eight
# product
# upgrade
# .
# To
# date
# ,
# night
# vision
# assist
# only
# detected
# pedestrians
# using
# a
# thermal
# imaging
# camera
# and
# highlighted
# them
# with
# yellow
# brackets
# .
# If
# the
# system
# detected
# a
# risk
# of
# collision
# with
# a
# pedestrian
# ,
# the
# system
# would
# output
# a
# graphic
# and
# an
# acoustic
# warning
# .
# Following
# the
# product
# upgrade
# ,
# the
# night
# vision
# assist
# in
# the
# Audi
# A
# eight
# now
# also
# detects
# large
# wild
# animals
# and
# highlights
# these
# in
# the
# thermal
# image
# displayed
# .
# The
# system
# warns
# the
# driver
# if
# there
# is
# a
# likelihood
# of
# an
# imminent
# collision
# with
# a
# wild
# animal
# .
# As
# a
# result
# ,
# the
# system
# is
# able
# to
# contribute
# further
# to
# supporting
# the
# driver
# in
# avoiding
# accidents
# .
# Anyone
# wishing
# to
# find
# out
# more
# information
# about
# Audi
# night
# vision
# assist
# can
# take
# a
# look
# at
# self
# -
# study
# program
# four
# six
# two
# .
# Audi
# A
# eight
# ten
# ,
# night
# vision
# assist
# .
# The
# head
# -
# up
# display
# resulting
# from
# the
# Audi
# A
# eight
# product
# upgrade
# is
# mainly
# based
# on
# the
# head
# up
# display
# in
# the
# Audi
# C
# seven
# .
# Only
# a
# few
# details
# have
# been
# modified
# .
# The
# displays
# are
# the
# same
# ,
# apart
# from
# one
# exception
# .
# The
# combined
# display
# of
# adaptive
# cruise
# control
# and
# Audi
# active
# lane
# assist
# has
# been
# removed
# .
# Instead
# ,
# a
# red
# warning
# symbol
# for
# the
# distance
# and
# collision
# warning
# system
# is
# projected
# onto
# the
# windscreen
# .
# The
# procedure
# for
# calibrating
# the
# head
# up
# display
# in
# customer
# service
# has
# remained
# the
# same
# as
# for
# the
# Audi
# A
# six
# and
# A
# seven
# .
# If
# you
# wish
# to
# learn
# more
# about
# the
# head
# up
# display
# ,
# please
# take
# a
# look
# at
# self
# -
# study
# program
# four
# eight
# two
# .
# Audi
# A
# seven
# Sportback
# ,
# head
# -
# up
# display
# and
# speed
# limit
# indicator
# .
# Anything
# you
# need
# to
# know
# about
# this
# system
# is
# described
# in
# this
# booklet
# .
# We
# always
# want
# to
# improve
# our
# programmes
# .
# Please
# send
# any
# suggestions
# ,
# improvements
# and
# topic
# requests
# you
# may
# have
# to
# Audi
# dot
# service
# dot
# T
# -
# V
# at
# Audi
# dot
# D
# -
# E
# .

# %% [markdown]
# # Morphology
# https://spacy.io/usage/linguistic-features#morphology

# %%
print("Pipeline:", nlp.pipe_names)
doc = nlp("I was reading the paper.")
token = doc[0]  # 'I'
print(token.morph)  # 'Case=Nom|Number=Sing|Person=1|PronType=Prs'
print(token.morph.get("PronType"))  # ['Prs']
# Out:
# Pipeline: ['tok2vec', 'parser', 'lemmatizer']
#
# []

# %% [markdown]
# # Constituency

# %% [markdown]
# # Collocation

# %% [markdown]
# # Word vectors

# %% [markdown]
# # Dependency

# %% [markdown]
# # Named entities
#
# Für einzelne Tokens: [Matcher](https://spacy.io/usage/rule-based-matching) \
# Für ganze Sätze: [Phrasematcher](https://spacy.io/usage/rule-based-matching#phrasematcher) \
# Ich schätze für den Moment sind wir nur an einzelnen Tokens interessiert? Oder an allen einzigartigen Token im ganzen Text?

# %%
from spacy.matcher import Matcher
from collections import defaultdict # 

# this works on the same example as above

nlp = spacy.load("en_core_web_sm")
# initialize the matcher, the vocab has to be the same as for the text
matcher = Matcher(nlp.vocab)

# idealy the user specifies what he wants to search and what attribute to assign?
terms = [[{"LOWER":"audi"}], [{"LOWER":"improvements"}], [{"LOWER":"parking"}]]

# also supports regular expressions:
terms += [[{"TEXT":{"REGEX":"^[Ii](\.?|f)$"}}]] # search for I, i, If, if

print("Query: {}".format(terms))

# add the terms to look for to the mathcer
matcher.add("Query", terms)

# load the data into doc
doc = nlp(data)
# run the matcher on the text in doc
matches = matcher(doc)

# get the indices (would correspond to corpus position from cwb?)
indices = [[start,end] for _,start,end in matches]

print(indices)

dict_out = defaultdict(list) # default dict initializes the value of a new key that is added with an empty list
                             # which we can then append to

# put the found indices to access the searched terms in a dictionary where they are available via said terms
# We have to go through all the found entities to confirm what term they correspond to...
# For large texts where we have many hits faster to split the query beforehand? Maybe parallel searching?
for index_pair in indices:
    dict_out["{}".format(doc[index_pair[0]:index_pair[1]])].append(index_pair)

# display the output
for key in dict_out:
    print("{} found at location {}.".format(key, dict_out[key]))

#for index in indices:
#    print('{} found at index location {}'.format(doc[index], index))

#print(matches)

#for match_id, start, end in matches:
#    string_id = nlp.vocab.strings[match_id] #Get string representation
#    span = doc[start:end] # matched span
#    print(match_id, string_id, start, end, span.text)
# Out:
# Query: [[{'LOWER': 'audi'}], [{'LOWER': 'improvements'}], [{'LOWER': 'parking'}], [{'TEXT': {'REGEX': '^[Ii](\\.?|f)$'}}]]
# [[14, 15], [54, 55], [55, 56], [60, 61], [64, 65], [91, 92], [97, 98], [124, 125], [129, 130], [160, 161], [164, 165], [169, 170], [180, 181], [192, 193], [209, 210], [211, 212], [223, 224], [232, 233], [255, 256], [266, 267], [311, 312], [312, 313], [349, 350], [359, 360], [391, 392], [399, 400], [454, 455], [460, 461], [467, 468], [472, 473], [478, 479], [497, 498], [515, 516], [525, 526], [530, 531], [544, 545], [564, 565], [576, 577], [595, 596], [617, 618], [629, 630], [656, 657], [690, 691], [713, 714], [754, 755], [771, 772], [788, 789], [803, 804], [834, 835], [879, 880], [886, 887], [911, 912], [952, 953], [960, 961], [968, 969]]
# Audi found at location [[14, 15], [54, 55], [55, 56], [60, 61], [64, 65], [91, 92], [97, 98], [124, 125], [129, 130], [160, 161], [164, 165], [169, 170], [180, 181], [192, 193], [211, 212], [223, 224], [232, 233], [266, 267], [312, 313], [399, 400], [467, 468], [472, 473], [497, 498], [544, 545], [576, 577], [595, 596], [617, 618], [629, 630], [690, 691], [754, 755], [771, 772], [788, 789], [803, 804], [834, 835], [879, 880], [911, 912], [960, 961], [968, 969]].
# If found at location [[209, 210], [311, 312], [391, 392], [564, 565], [656, 657], [886, 887]].
# if found at location [[255, 256], [349, 350], [460, 461], [530, 531], [713, 714]].
# I found at location [[359, 360]].
# parking found at location [[454, 455], [478, 479], [515, 516], [525, 526]].
# improvements found at location [[952, 953]].

# %%
# can also search for words of certain length or above/below certain lengths
matcher = Matcher(nlp.vocab)

pattern = [[{"LENGTH":{"==":10}}]]#, [{"LENGTH":{"<=":1}}], [{"LENGTH":{">=":12}}]]

matcher.add("Query", pattern)
matches = matcher(doc)

indices = [[start,end] for _,start,end in matches]

dict_out = defaultdict(list)

for index_pair in indices:
    dict_out["{}".format(doc[index_pair[0]:index_pair[1]])].append(index_pair)

for key in dict_out:
    print("{} found at location {}.".format(key, dict_out[key]))
# Out:
# changeover found at location [[76, 77]].
# intervenes found at location [[144, 145]].
# innovative found at location [[202, 203]].
# suppressed found at location [[281, 282], [304, 305]].
# technology found at location [[420, 421], [573, 574]].
# determines found at location [[547, 548]].
# ultrasonic found at location [[554, 555]].
# pedestrian found at location [[666, 667]].
# highlights found at location [[700, 701]].
# likelihood found at location [[717, 718]].
# contribute found at location [[736, 737]].
# supporting found at location [[739, 740]].
# windscreen found at location [[859, 860]].
# programmes found at location [[945, 946]].

# %%
# search for token pattern

matcher = Matcher(nlp.vocab)

# seach for the different types of cars with a "wildcard token pattern" leaving the last token empty
pattern = [[{"ORTH":"Audi"}, {"ORTH": "A"}, {}]] 

matcher.add("Query", pattern)

matches = matcher(doc)

indices = [[start,end] for _,start,end in matches]

for _, start, end in matches:
    indices.append([start, end])

dict_out = defaultdict(list)

for index_pair in indices:
    dict_out["{}".format(doc[index_pair[0]:index_pair[1]])].append(index_pair)

for key in dict_out:
    print("{} found at location {}.".format(key, dict_out[key]))
# Out:
# Audi A eight found at location [[14, 17], [97, 100], [124, 127], [180, 183], [232, 235], [472, 475], [629, 632], [690, 693], [771, 774], [788, 791], [14, 17], [97, 100], [124, 127], [180, 183], [232, 235], [472, 475], [629, 632], [690, 693], [771, 774], [788, 791]].
# Audi A six found at location [[160, 163], [192, 195], [497, 500], [879, 882], [160, 163], [192, 195], [497, 500], [879, 882]].
# Audi A seven found at location [[164, 167], [911, 914], [164, 167], [911, 914]].

# %%
# put it in a function

def search_text(query, nlp, doc):
    matcher = Matcher(nlp.vocab)

    matcher.add("Query", query)

    matches = matcher(doc)

    indices = [[start,end] for _,start,end in matches]

    dict_out = defaultdict(list)

    for index_pair in indices:
        dict_out["{}".format(doc[index_pair[0]:index_pair[1]])].append(index_pair)

    #for key in dict_out:
    #    print("{} found at location {}.".format(key, dict_out[key]))
    return dict_out

# %%
query = [[{"ORTH":"Audi"}, {"ORTH": "A"}, {}]] 

test1 = search_text(query, nlp, doc)

print(test1)

print('*'*50)

# can just add different queries together
query += terms

test2 = search_text(query, nlp, doc)

print(test2)
# Out:
# defaultdict(<class 'list'>, {'Audi A eight': [[14, 17], [97, 100], [124, 127], [180, 183], [232, 235], [472, 475], [629, 632], [690, 693], [771, 774], [788, 791]], 'Audi A six': [[160, 163], [192, 195], [497, 500], [879, 882]], 'Audi A seven': [[164, 167], [911, 914]]})
# **************************************************
# defaultdict(<class 'list'>, {'Audi': [[14, 15], [54, 55], [55, 56], [60, 61], [64, 65], [91, 92], [97, 98], [124, 125], [129, 130], [160, 161], [164, 165], [169, 170], [180, 181], [192, 193], [211, 212], [223, 224], [232, 233], [266, 267], [312, 313], [399, 400], [467, 468], [472, 473], [497, 498], [544, 545], [576, 577], [595, 596], [617, 618], [629, 630], [690, 691], [754, 755], [771, 772], [788, 789], [803, 804], [834, 835], [879, 880], [911, 912], [960, 961], [968, 969]], 'Audi A eight': [[14, 17], [97, 100], [124, 127], [180, 183], [232, 235], [472, 475], [629, 632], [690, 693], [771, 774], [788, 791]], 'Audi A six': [[160, 163], [192, 195], [497, 500], [879, 882]], 'Audi A seven': [[164, 167], [911, 914]], 'If': [[209, 210], [311, 312], [391, 392], [564, 565], [656, 657], [886, 887]], 'if': [[255, 256], [349, 350], [460, 461], [530, 531], [713, 714]], 'I': [[359, 360]], 'parking': [[454, 455], [478, 479], [515, 516], [525, 526]], 'improvements': [[952, 953]]})

# %%
def get_unique(doc):
    """Get number of unique words in doc"""
    
    out = 0
    seen = set()
    for token in doc:
        if token.text not in seen:
            out+=1
        seen.add(token.text)
    return out

# %%
def search_token(query, nlp, doc):
    """search text for specific token and return all the found locations in dict."""

    matcher = Matcher(nlp.vocab)

    matcher.add("Query", query)

    matches = matcher(doc)

    indices = [[start,end] for _,start,end in matches]

    dict_out = defaultdict(list)

    dict_out["{}".format(doc[indices[0][0]:indices[0][1]])].append(indices)

    #for key in dict_out:
    #    print("{} found at location {}.".format(key, dict_out[key]))
    return dict_out

# %%
def named_entities(nlp, doc):
    """Get locations for all umique words in doc into a dictionary, case sensitive"""
    
    named_entities = None

    # get the number of unique tokens in text, may save some time in some cases
    # still worth it for large corpora?
    unique = get_unique(doc)

    for token in doc:
        
        if named_entities:
            # if the dictionary is not empty:
            if token.text in named_entities:
                # if the token is already in the dictionary:
                pass
            elif token.text not in named_entities:
                # if the token is not already in there add it:
                named_entities.update(search_token([[{"ORTH":"{}".format(token)}]], nlp, doc))
        else:
            # if the dictionary hasn't been initialized do so with first token
            named_entities = search_token([[{"ORTH":"{}".format(token)}]], nlp, doc)
        
        if len(named_entities) == unique:
            # if we have passed each unique word already there is no need to continue
            break

    return named_entities

# %%
named_ent = named_entities(nlp, doc)

# %%
for key in named_ent:
    print("{}: {}".format(key, named_ent[key]))
# Out:
# As: [[[0, 1], [369, 370], [727, 728]]]
# part: [[[1, 2]]]
# of: [[[2, 3], [9, 10], [20, 21], [35, 36], [275, 276], [289, 290], [342, 343], [423, 424], [466, 467], [487, 488], [537, 538], [550, 551], [560, 561], [662, 663], [718, 719], [829, 830]]]
# the: [[[3, 4], [7, 8], [13, 14], [33, 34], [48, 49], [70, 71], [96, 97], [105, 106], [117, 118], [123, 124], [140, 141], [146, 147], [159, 160], [179, 180], [188, 189], [191, 192], [215, 216], [231, 232], [247, 248], [256, 257], [273, 274], [287, 288], [295, 296], [320, 321], [329, 330], [354, 355], [365, 366], [373, 374], [382, 383], [419, 420], [424, 425], [445, 446], [457, 458], [464, 465], [471, 472], [476, 477], [496, 497], [517, 518], [535, 536], [538, 539], [548, 549], [551, 552], [558, 559], [561, 562], [572, 573], [614, 615], [628, 629], [657, 658], [668, 669], [680, 681], [684, 685], [689, 690], [703, 704], [711, 712], [731, 732], [740, 741], [787, 788], [797, 798], [802, 803], [818, 819], [849, 850], [858, 859], [865, 866], [874, 875], [878, 879], [893, 894]]]
# product: [[[4, 5], [118, 119], [632, 633], [681, 682], [791, 792]]]
# upgrade: [[[5, 6], [119, 120], [633, 634], [682, 683], [792, 793]]]
# at: [[[6, 7], [47, 48], [381, 382], [407, 408], [533, 534], [587, 588], [762, 763], [902, 903], [967, 968]]]
# end: [[[8, 9]]]
# twenty: [[[10, 11], [601, 602]]]
# thirteen: [[[11, 12]]]
# ,: [[[12, 13], [59, 60], [63, 64], [68, 69], [109, 110], [127, 128], [137, 138], [173, 174], [183, 184], [200, 201], [214, 215], [219, 220], [227, 228], [235, 236], [254, 255], [272, 273], [298, 299], [305, 306], [323, 324], [346, 347], [348, 349], [360, 361], [372, 373], [403, 404], [444, 445], [475, 476], [503, 504], [516, 517], [579, 580], [611, 612], [637, 638], [667, 668], [683, 684], [730, 731], [775, 776], [820, 821], [843, 844], [897, 898], [915, 916], [951, 952]]]
# Audi: [[[14, 15], [54, 55], [55, 56], [60, 61], [64, 65], [91, 92], [97, 98], [124, 125], [129, 130], [160, 161], [164, 165], [169, 170], [180, 181], [192, 193], [211, 212], [223, 224], [232, 233], [266, 267], [312, 313], [399, 400], [467, 468], [472, 473], [497, 498], [544, 545], [576, 577], [595, 596], [617, 618], [629, 630], [690, 691], [754, 755], [771, 772], [788, 789], [803, 804], [834, 835], [879, 880], [911, 912], [960, 961], [968, 969]]]
# A: [[[15, 16], [98, 99], [125, 126], [161, 162], [165, 166], [181, 182], [193, 194], [196, 197], [233, 234], [458, 459], [473, 474], [498, 499], [501, 502], [630, 631], [691, 692], [772, 773], [789, 790], [880, 881], [883, 884], [912, 913]]]
# eight: [[[16, 17], [99, 100], [126, 127], [182, 183], [234, 235], [413, 414], [459, 460], [474, 475], [631, 632], [692, 693], [773, 774], [790, 791], [908, 909]]]
# gained: [[[17, 18]]]
# a: [[[18, 19], [262, 263], [276, 277], [324, 325], [343, 344], [362, 363], [370, 371], [405, 406], [524, 525], [585, 586], [623, 624], [645, 646], [660, 661], [665, 666], [672, 673], [716, 717], [723, 724], [728, 729], [760, 761], [808, 809], [844, 845], [900, 901]]]
# number: [[[19, 20]]]
# new: [[[21, 22], [30, 31], [203, 204], [296, 297], [596, 597], [625, 626]]]
# features: [[[22, 23], [31, 32]]]
# relating: [[[23, 24]]]
# to: [[[24, 25], [80, 81], [89, 90], [104, 105], [187, 188], [387, 388], [395, 396], [509, 510], [557, 558], [568, 569], [735, 736], [738, 739], [748, 749], [889, 890], [928, 929], [942, 943], [959, 960]]]
# driver: [[[25, 26], [50, 51], [257, 258], [374, 375], [446, 447], [597, 598], [605, 606], [712, 713], [741, 742]]]
# assist: [[[26, 27], [51, 52], [58, 59], [62, 63], [67, 68], [94, 95], [131, 132], [172, 173], [213, 214], [218, 219], [226, 227], [239, 240], [269, 270], [314, 315], [402, 403], [439, 440], [469, 470], [546, 547], [578, 579], [598, 599], [620, 621], [640, 641], [687, 688], [757, 758], [778, 779], [837, 838]]]
# systems: [[[27, 28], [52, 53], [240, 241], [440, 441], [599, 600]]]
# .: [[[28, 29], [42, 43], [74, 75], [102, 103], [115, 116], [148, 149], [168, 169], [198, 199], [208, 209], [243, 244], [251, 252], [282, 283], [293, 294], [310, 311], [335, 336], [368, 369], [390, 391], [415, 416], [428, 429], [441, 442], [462, 463], [489, 490], [512, 513], [543, 544], [563, 564], [594, 595], [603, 604], [616, 617], [634, 635], [655, 656], [678, 679], [707, 708], [726, 727], [745, 746], [770, 771], [779, 780], [806, 807], [814, 815], [825, 826], [841, 842], [860, 861], [885, 886], [910, 911], [924, 925], [938, 939], [946, 947], [973, 974]]]
# These: [[[29, 30]]]
# are: [[[32, 33], [228, 229], [817, 818]]]
# topic: [[[34, 35], [954, 955]]]
# this: [[[36, 37], [110, 111], [135, 136], [299, 300], [350, 351], [485, 486], [931, 932], [936, 937]]]
# service: [[[37, 38], [871, 872], [962, 963]]]
# T: [[[38, 39], [964, 965]]]
# -: [[[39, 40], [356, 357], [358, 359], [409, 410], [589, 590], [764, 765], [782, 783], [904, 905], [917, 918], [965, 966], [971, 972]]]
# V: [[[40, 41], [966, 967]]]
# programme: [[[41, 42]]]
# We: [[[43, 44], [939, 940]]]
# will: [[[44, 45], [447, 448], [519, 520]]]
# be: [[[45, 46], [449, 450], [482, 483], [510, 511], [521, 522]]]
# looking: [[[46, 47]]]
# following: [[[49, 50], [248, 249], [627, 628]]]
# :: [[[53, 54]]]
# active: [[[56, 57], [92, 93], [170, 171], [224, 225], [267, 268], [400, 401], [434, 435], [835, 836]]]
# Lane: [[[57, 58]]]
# park: [[[61, 62], [468, 469], [545, 546], [577, 578]]]
# night: [[[65, 66], [618, 619], [638, 639], [685, 686], [755, 756], [776, 777]]]
# vision: [[[66, 67], [619, 620], [639, 640], [686, 687], [756, 757], [777, 778]]]
# and: [[[69, 70], [163, 164], [195, 196], [260, 261], [347, 348], [421, 422], [500, 501], [649, 650], [674, 675], [699, 700], [833, 834], [851, 852], [882, 883], [920, 921], [953, 954]]]
# head: [[[71, 72], [781, 782], [798, 799], [866, 867], [894, 895], [916, 917]]]
# up: [[[72, 73], [783, 784], [799, 800], [867, 868], [895, 896], [918, 919]]]
# display: [[[73, 74], [784, 785], [800, 801], [828, 829], [868, 869], [896, 897], [919, 920]]]
# The: [[[75, 76], [336, 337], [490, 491], [604, 605], [708, 709], [780, 781], [815, 816], [826, 827], [861, 862]]]
# changeover: [[[76, 77]]]
# from: [[[77, 78], [495, 496], [786, 787], [822, 823]]]
# hydraulical: [[[78, 79]]]
# steering: [[[79, 80], [82, 83], [107, 108], [114, 115], [147, 148], [344, 345], [366, 367], [430, 431], [435, 436]]]
# electromechanical: [[[81, 82], [113, 114]]]
# now: [[[83, 84], [157, 158], [176, 177], [621, 622], [693, 694]]]
# means: [[[84, 85], [341, 342]]]
# that: [[[85, 86], [142, 143], [286, 287], [378, 379], [523, 524], [582, 583]]]
# it: [[[86, 87], [531, 532]]]
# is: [[[87, 88], [175, 176], [184, 185], [301, 302], [326, 327], [338, 339], [351, 352], [375, 376], [527, 528], [532, 533], [606, 607], [715, 716], [733, 734], [793, 794], [855, 856], [933, 934]]]
# possible: [[[88, 89]]]
# offer: [[[90, 91]]]
# lane: [[[93, 94], [130, 131], [171, 172], [216, 217], [225, 226], [259, 260], [268, 269], [290, 291], [322, 323], [380, 381], [401, 402], [438, 439], [836, 837]]]
# in: [[[95, 96], [145, 146], [178, 179], [190, 191], [230, 231], [319, 320], [353, 354], [364, 365], [426, 427], [437, 438], [456, 457], [470, 471], [575, 576], [600, 601], [613, 614], [688, 689], [702, 703], [742, 743], [801, 802], [869, 870], [935, 936]]]
# as: [[[100, 101], [220, 221], [222, 223], [876, 877]]]
# well: [[[101, 102], [221, 222]]]
# Due: [[[103, 104]]]
# planned: [[[106, 107]]]
# interventions: [[[108, 109]]]
# system: [[[111, 112], [189, 190], [249, 250], [297, 298], [425, 426], [479, 480], [491, 492], [658, 659], [669, 670], [709, 710], [732, 733], [854, 855], [932, 933]]]
# requires: [[[112, 113]]]
# Until: [[[116, 117]]]
# took: [[[120, 121]]]
# place: [[[121, 122]]]
# on: [[[122, 123], [134, 135], [158, 159], [796, 797]]]
# only: [[[128, 129], [432, 433], [520, 521], [641, 642]]]
# was: [[[132, 133], [270, 271], [284, 285], [291, 292]]]
# offered: [[[133, 134], [607, 608]]]
# model: [[[136, 137], [167, 168]]]
# but: [[[138, 139], [306, 307]]]
# not: [[[139, 140], [431, 432]]]
# version: [[[141, 142], [150, 151]]]
# actively: [[[143, 144]]]
# intervenes: [[[144, 145]]]
# This: [[[149, 150], [416, 417]]]
# has: [[[151, 152], [205, 206], [492, 493], [838, 839], [872, 873]]]
# been: [[[152, 153], [206, 207], [280, 281], [333, 334], [493, 494], [812, 813], [839, 840]]]
# available: [[[153, 154], [177, 178]]]
# for: [[[154, 155], [484, 485], [848, 849], [863, 864], [877, 878]]]
# some: [[[155, 156]]]
# time: [[[156, 157], [384, 385]]]
# six: [[[162, 163], [194, 195], [499, 500], [592, 593], [768, 769], [881, 882]]]
# seven: [[[166, 167], [197, 198], [502, 503], [805, 806], [884, 885], [913, 914]]]
# which: [[[174, 175]]]
# very: [[[185, 186]]]
# similar: [[[186, 187]]]
# However: [[[199, 200]]]
# one: [[[201, 202], [308, 309], [505, 506], [541, 542], [823, 824]]]
# innovative: [[[202, 203]]]
# feature: [[[204, 205]]]
# added: [[[207, 208], [609, 610]]]
# If: [[[209, 210], [311, 312], [391, 392], [564, 565], [656, 657], [886, 887]]]
# both: [[[210, 211]]]
# side: [[[212, 213], [313, 314], [559, 560]]]
# change: [[[217, 218], [288, 289]]]
# present: [[[229, 230], [383, 384]]]
# then: [[[236, 237]]]
# these: [[[237, 238], [701, 702]]]
# two: [[[238, 239], [769, 770], [909, 910]]]
# exchange: [[[241, 242]]]
# data: [[[242, 243]]]
# Doing: [[[244, 245]]]
# so: [[[245, 246]]]
# enables: [[[246, 247], [433, 434]]]
# optimisation: [[[250, 251]]]
# To: [[[252, 253], [635, 636]]]
# date: [[[253, 254], [636, 637]]]
# if: [[[255, 256], [349, 350], [460, 461], [530, 531], [713, 714]]]
# changed: [[[258, 259]]]
# set: [[[261, 262], [334, 335]]]
# direction: [[[263, 264], [330, 331]]]
# indicator: [[[264, 265], [331, 332], [923, 924]]]
# while: [[[265, 266]]]
# activated: [[[271, 272], [352, 353]]]
# output: [[[274, 275], [671, 672]]]
# warning: [[[277, 278], [300, 301], [325, 326], [337, 338], [677, 678], [846, 847], [853, 854]]]
# would: [[[278, 279], [393, 394], [566, 567], [670, 671]]]
# have: [[[279, 280], [811, 812], [958, 959]]]
# suppressed: [[[281, 282], [304, 305]]]
# It: [[[283, 284]]]
# assumed: [[[285, 286]]]
# intentional: [[[292, 293]]]
# In: [[[294, 295], [442, 443]]]
# also: [[[302, 303], [448, 449], [481, 482], [694, 695]]]
# normally: [[[303, 304]]]
# with: [[[307, 308], [652, 653], [664, 665], [722, 723]]]
# exception: [[[309, 310], [824, 825]]]
# detects: [[[315, 316], [695, 696]]]
# an: [[[316, 317], [388, 389], [675, 676], [719, 720]]]
# approaching: [[[317, 318]]]
# vehicle: [[[318, 319], [488, 489], [539, 540], [562, 563]]]
# neighbouring: [[[321, 322]]]
# given: [[[327, 328], [339, 340]]]
# despite: [[[328, 329]]]
# having: [[[332, 333]]]
# by: [[[340, 341]]]
# intervention: [[[345, 346], [436, 437]]]
# M: [[[355, 356], [357, 358]]]
# I: [[[359, 360]]]
# via: [[[361, 362]]]
# vibration: [[[363, 364]]]
# wheel: [[[367, 368]]]
# result: [[[371, 372], [729, 730]]]
# made: [[[376, 377]]]
# aware: [[[377, 378]]]
# changing: [[[379, 380]]]
# could: [[[385, 386]]]
# lead: [[[386, 387]]]
# accident: [[[389, 390]]]
# you: [[[392, 393], [565, 566], [583, 584], [887, 888], [926, 927], [956, 957]]]
# like: [[[394, 395], [567, 568]]]
# learn: [[[396, 397], [890, 891]]]
# more: [[[397, 398], [570, 571], [751, 752], [891, 892]]]
# about: [[[398, 399], [571, 572], [753, 754], [892, 893], [930, 931]]]
# take: [[[404, 405], [584, 585], [759, 760], [899, 900]]]
# look: [[[406, 407], [586, 587], [761, 762], [901, 902]]]
# self: [[[408, 409], [588, 589], [763, 764], [903, 904]]]
# study: [[[410, 411], [590, 591], [765, 766], [905, 906]]]
# program: [[[411, 412], [591, 592], [766, 767], [906, 907]]]
# four: [[[412, 413], [767, 768], [907, 908]]]
# three: [[[414, 415]]]
# booklet: [[[417, 418], [937, 938]]]
# describes: [[[418, 419]]]
# technology: [[[420, 421], [573, 574]]]
# functions: [[[422, 423]]]
# detail: [[[427, 428]]]
# Electromechanical: [[[429, 430]]]
# future: [[[443, 444]]]
# assisted: [[[450, 451]]]
# when: [[[451, 452]]]
# driving: [[[452, 453]]]
# into: [[[453, 454]]]
# parking: [[[454, 455], [478, 479], [515, 516], [525, 526]]]
# spaces: [[[455, 456]]]
# required: [[[461, 462]]]
# With: [[[463, 464]]]
# introduction: [[[465, 466]]]
# semiautomated: [[[477, 478]]]
# can: [[[480, 481], [758, 759]]]
# ordered: [[[483, 484]]]
# class: [[[486, 487]]]
# taken: [[[494, 495]]]
# although: [[[504, 505]]]
# major: [[[506, 507], [624, 625]]]
# parameter: [[[507, 508]]]
# had: [[[508, 509]]]
# adapted: [[[511, 512]]]
# When: [[[513, 514]]]
# parallel: [[[514, 515]]]
# customer: [[[518, 519], [870, 871]]]
# told: [[[522, 523]]]
# space: [[[526, 527], [552, 553]]]
# sufficiently: [[[528, 529]]]
# long: [[[529, 530]]]
# least: [[[534, 535]]]
# length: [[[536, 537], [549, 550]]]
# plus: [[[540, 541]]]
# metre: [[[542, 543]]]
# determines: [[[547, 548]]]
# using: [[[553, 554], [644, 645]]]
# ultrasonic: [[[554, 555]]]
# sensors: [[[555, 556]]]
# fitted: [[[556, 557]]]
# read: [[[569, 570]]]
# used: [[[574, 575]]]
# we: [[[580, 581]]]
# recommend: [[[581, 582]]]
# hundred: [[[593, 594]]]
# eleven: [[[602, 603]]]
# real: [[[608, 609]]]
# value: [[[610, 611]]]
# even: [[[612, 613]]]
# dark: [[[615, 616]]]
# boasts: [[[622, 623]]]
# function: [[[626, 627]]]
# detected: [[[642, 643], [659, 660]]]
# pedestrians: [[[643, 644]]]
# thermal: [[[646, 647], [704, 705]]]
# imaging: [[[647, 648]]]
# camera: [[[648, 649]]]
# highlighted: [[[650, 651]]]
# them: [[[651, 652]]]
# yellow: [[[653, 654]]]
# brackets: [[[654, 655]]]
# risk: [[[661, 662]]]
# collision: [[[663, 664], [721, 722], [852, 853]]]
# pedestrian: [[[666, 667]]]
# graphic: [[[673, 674]]]
# acoustic: [[[676, 677]]]
# Following: [[[679, 680]]]
# large: [[[696, 697]]]
# wild: [[[697, 698], [724, 725]]]
# animals: [[[698, 699]]]
# highlights: [[[700, 701]]]
# image: [[[705, 706]]]
# displayed: [[[706, 707]]]
# warns: [[[710, 711]]]
# there: [[[714, 715]]]
# likelihood: [[[717, 718]]]
# imminent: [[[720, 721]]]
# animal: [[[725, 726]]]
# able: [[[734, 735]]]
# contribute: [[[736, 737]]]
# further: [[[737, 738]]]
# supporting: [[[739, 740]]]
# avoiding: [[[743, 744]]]
# accidents: [[[744, 745]]]
# Anyone: [[[746, 747]]]
# wishing: [[[747, 748]]]
# find: [[[749, 750]]]
# out: [[[750, 751]]]
# information: [[[752, 753]]]
# ten: [[[774, 775]]]
# resulting: [[[785, 786]]]
# mainly: [[[794, 795]]]
# based: [[[795, 796]]]
# C: [[[804, 805]]]
# Only: [[[807, 808]]]
# few: [[[809, 810]]]
# details: [[[810, 811]]]
# modified: [[[813, 814]]]
# displays: [[[816, 817]]]
# same: [[[819, 820], [875, 876]]]
# apart: [[[821, 822]]]
# combined: [[[827, 828]]]
# adaptive: [[[830, 831]]]
# cruise: [[[831, 832]]]
# control: [[[832, 833]]]
# removed: [[[840, 841]]]
# Instead: [[[842, 843]]]
# red: [[[845, 846]]]
# symbol: [[[847, 848]]]
# distance: [[[850, 851]]]
# projected: [[[856, 857]]]
# onto: [[[857, 858]]]
# windscreen: [[[859, 860]]]
# procedure: [[[862, 863]]]
# calibrating: [[[864, 865]]]
# remained: [[[873, 874]]]
# wish: [[[888, 889]]]
# please: [[[898, 899]]]
# Sportback: [[[914, 915]]]
# speed: [[[921, 922]]]
# limit: [[[922, 923]]]
# Anything: [[[925, 926]]]
# need: [[[927, 928]]]
# know: [[[929, 930]]]
# described: [[[934, 935]]]
# always: [[[940, 941]]]
# want: [[[941, 942]]]
# improve: [[[943, 944]]]
# our: [[[944, 945]]]
# programmes: [[[945, 946]]]
# Please: [[[947, 948]]]
# send: [[[948, 949]]]
# any: [[[949, 950]]]
# suggestions: [[[950, 951]]]
# improvements: [[[952, 953]]]
# requests: [[[955, 956]]]
# may: [[[957, 958]]]
# dot: [[[961, 962], [963, 964], [969, 970]]]
# D: [[[970, 971]]]
# E: [[[972, 973]]]

# %%
print(len(named_ent))
# Out:
# 313
